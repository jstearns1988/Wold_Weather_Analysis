# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of 2000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Get the nearest city using the citypy module
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Import dependencies for API call
import requests
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve weather data information from the API call
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | airai
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | aklavik
# Processing Record 6 of Set 1 | davila
# Processing Record 7 of Set 1 | yueyang
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | lakselv
# Processing Record 12 of Set 1 | lichuan
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | lar
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | gravdal
# Processing Record 18 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | porto de moz
# Processing Record 21 of Set 1 | qarayeri
# Processing Record 22 of Set 1 | alice springs
# Processing Record 23 of Set 1 | kirkwall
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | antofagasta
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | prince albert
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | broome
# Processing Record 37 of Set 1 | mendi
# Processing Record 38 of Set 1 | rio gallegos
# Processing Record 39 of Set 1 | norman wells
# Processing Record 40 of Set 1 | omboue
# Processing Record 41 of Set 1 | belmonte
# Processing Record 42 of Set 1 | kumo
# Processing Record 43 of Set 1 | ye
# City not found. Skipping...
# Processing Record 44 of Set 1 | dunedin
# Processing Record 45 of Set 1 | new norfolk
# Processing Record 46 of Set 1 | cuamba
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | storsteinnes
# Processing Record 50 of Set 1 | hobyo
# Processing Record 1 of Set 2 | sardarshahr
# Processing Record 2 of Set 2 | malko tarnovo
# Processing Record 3 of Set 2 | pevek
# Processing Record 4 of Set 2 | saint-philippe
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | portlethen
# Processing Record 7 of Set 2 | eyl
# Processing Record 8 of Set 2 | doba
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | atikokan
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | katobu
# Processing Record 13 of Set 2 | coquimbo
# Processing Record 14 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 2 | avera
# Processing Record 16 of Set 2 | omsukchan
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | sisimiut
# Processing Record 19 of Set 2 | piacabucu
# Processing Record 20 of Set 2 | najran
# Processing Record 21 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | inta
# Processing Record 24 of Set 2 | leningradskiy
# Processing Record 25 of Set 2 | san patricio
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | taksimo
# Processing Record 28 of Set 2 | witu
# Processing Record 29 of Set 2 | busselton
# Processing Record 30 of Set 2 | loveland
# Processing Record 31 of Set 2 | killybegs
# Processing Record 32 of Set 2 | skiros
# City not found. Skipping...
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | sambava
# Processing Record 35 of Set 2 | muros
# Processing Record 36 of Set 2 | beringovskiy
# Processing Record 37 of Set 2 | yellowknife
# Processing Record 38 of Set 2 | zonguldak
# Processing Record 39 of Set 2 | tateyama
# Processing Record 40 of Set 2 | hazaribag
# Processing Record 41 of Set 2 | noshiro
# Processing Record 42 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 2 | mutsu
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | lerwick
# Processing Record 46 of Set 2 | cayenne
# Processing Record 47 of Set 2 | cairns
# Processing Record 48 of Set 2 | isangel
# Processing Record 49 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 2 | guymon
# Processing Record 1 of Set 3 | sao joao da barra
# Processing Record 2 of Set 3 | bluff
# Processing Record 3 of Set 3 | sioux lookout
# Processing Record 4 of Set 3 | seymchan
# Processing Record 5 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 3 | krasnyy yar
# Processing Record 7 of Set 3 | punta arenas
# Processing Record 8 of Set 3 | carutapera
# Processing Record 9 of Set 3 | erenhot
# Processing Record 10 of Set 3 | sanford
# Processing Record 11 of Set 3 | marau
# Processing Record 12 of Set 3 | ostrovnoy
# Processing Record 13 of Set 3 | dedougou
# Processing Record 14 of Set 3 | jiaojiang
# Processing Record 15 of Set 3 | kavaratti
# Processing Record 16 of Set 3 | sibu
# Processing Record 17 of Set 3 | rocha
# Processing Record 18 of Set 3 | karratha
# Processing Record 19 of Set 3 | taywarah
# Processing Record 20 of Set 3 | padang
# Processing Record 21 of Set 3 | castro
# Processing Record 22 of Set 3 | mount abu
# Processing Record 23 of Set 3 | mahinog
# Processing Record 24 of Set 3 | lebu
# Processing Record 25 of Set 3 | waipawa
# Processing Record 26 of Set 3 | rock sound
# Processing Record 27 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 3 | saint-leu
# Processing Record 29 of Set 3 | zyryanka
# Processing Record 30 of Set 3 | valparaiso
# Processing Record 31 of Set 3 | wanaka
# Processing Record 32 of Set 3 | port-gentil
# Processing Record 33 of Set 3 | haines junction
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | port hardy
# Processing Record 36 of Set 3 | saint george
# Processing Record 37 of Set 3 | shimoda
# Processing Record 38 of Set 3 | polunochnoye
# Processing Record 39 of Set 3 | palmer
# Processing Record 40 of Set 3 | georgetown
# Processing Record 41 of Set 3 | ekhabi
# Processing Record 42 of Set 3 | cidreira
# Processing Record 43 of Set 3 | hovd
# Processing Record 44 of Set 3 | ayan
# Processing Record 45 of Set 3 | ugoofaaru
# Processing Record 46 of Set 3 | wajir
# Processing Record 47 of Set 3 | urambo
# Processing Record 48 of Set 3 | obregon
# Processing Record 49 of Set 3 | alta floresta
# Processing Record 50 of Set 3 | jiazi
# Processing Record 1 of Set 4 | cherskiy
# Processing Record 2 of Set 4 | nome
# Processing Record 3 of Set 4 | ponta delgada
# Processing Record 4 of Set 4 | nemuro
# Processing Record 5 of Set 4 | port lincoln
# Processing Record 6 of Set 4 | kiama
# Processing Record 7 of Set 4 | tuktoyaktuk
# Processing Record 8 of Set 4 | surgut
# Processing Record 9 of Set 4 | miri
# Processing Record 10 of Set 4 | mar del plata
# Processing Record 11 of Set 4 | mizdah
# Processing Record 12 of Set 4 | kaseda
# Processing Record 13 of Set 4 | butaritari
# Processing Record 14 of Set 4 | kruisfontein
# Processing Record 15 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 4 | khasan
# Processing Record 17 of Set 4 | slonim
# Processing Record 18 of Set 4 | bambous virieux
# Processing Record 19 of Set 4 | sovetskiy
# Processing Record 20 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 4 | nueva loja
# Processing Record 22 of Set 4 | sola
# Processing Record 23 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 4 | tuatapere
# Processing Record 25 of Set 4 | saint-louis
# Processing Record 26 of Set 4 | muborak
# Processing Record 27 of Set 4 | hamilton
# Processing Record 28 of Set 4 | jubayl
# City not found. Skipping...
# Processing Record 29 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 4 | novikovo
# Processing Record 31 of Set 4 | the valley
# Processing Record 32 of Set 4 | port moresby
# Processing Record 33 of Set 4 | las guacamayas
# Processing Record 34 of Set 4 | codrington
# Processing Record 35 of Set 4 | jiaonan
# Processing Record 36 of Set 4 | dolores
# Processing Record 37 of Set 4 | vila
# Processing Record 38 of Set 4 | luoyang
# Processing Record 39 of Set 4 | inhambane
# Processing Record 40 of Set 4 | korla
# Processing Record 41 of Set 4 | chiang rai
# Processing Record 42 of Set 4 | amuntai
# Processing Record 43 of Set 4 | pochutla
# Processing Record 44 of Set 4 | hofn
# Processing Record 45 of Set 4 | kalomo
# City not found. Skipping...
# Processing Record 46 of Set 4 | bengkulu
# Processing Record 47 of Set 4 | bathsheba
# Processing Record 48 of Set 4 | lazaro cardenas
# Processing Record 49 of Set 4 | kijang
# Processing Record 50 of Set 4 | igurusi
# Processing Record 1 of Set 5 | victoria
# Processing Record 2 of Set 5 | severo-yeniseyskiy
# Processing Record 3 of Set 5 | souillac
# Processing Record 4 of Set 5 | port alfred
# Processing Record 5 of Set 5 | saint anthony
# Processing Record 6 of Set 5 | marsa matruh
# Processing Record 7 of Set 5 | mount gambier
# Processing Record 8 of Set 5 | bredasdorp
# Processing Record 9 of Set 5 | esperance
# Processing Record 10 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 5 | san pedro del parana
# Processing Record 12 of Set 5 | chuy
# Processing Record 13 of Set 5 | dingle
# Processing Record 14 of Set 5 | kenai
# Processing Record 15 of Set 5 | vestmannaeyjar
# Processing Record 16 of Set 5 | talakan
# Processing Record 17 of Set 5 | birao
# Processing Record 18 of Set 5 | yulara
# Processing Record 19 of Set 5 | ndele
# Processing Record 20 of Set 5 | poum
# Processing Record 21 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 22 of Set 5 | oranjemund
# Processing Record 23 of Set 5 | samarai
# Processing Record 24 of Set 5 | hualmay
# Processing Record 25 of Set 5 | asau
# Processing Record 26 of Set 5 | luau
# Processing Record 27 of Set 5 | jamestown
# Processing Record 28 of Set 5 | srednekolymsk
# Processing Record 29 of Set 5 | torbay
# Processing Record 30 of Set 5 | ishigaki
# Processing Record 31 of Set 5 | dauphin
# Processing Record 32 of Set 5 | shubarkuduk
# Processing Record 33 of Set 5 | vostok
# Processing Record 34 of Set 5 | one hundred mile house
# City not found. Skipping...
# Processing Record 35 of Set 5 | cavite
# Processing Record 36 of Set 5 | tromso
# Processing Record 37 of Set 5 | kavieng
# Processing Record 38 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 39 of Set 5 | luderitz
# Processing Record 40 of Set 5 | saint-francois
# Processing Record 41 of Set 5 | half moon bay
# Processing Record 42 of Set 5 | tiksi
# Processing Record 43 of Set 5 | cockburn town
# Processing Record 44 of Set 5 | mmathubudukwane
# Processing Record 45 of Set 5 | hohhot
# Processing Record 46 of Set 5 | hoquiam
# Processing Record 47 of Set 5 | santiago de cao
# Processing Record 48 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 5 | chokurdakh
# Processing Record 50 of Set 5 | mayo
# Processing Record 1 of Set 6 | lafia
# Processing Record 2 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 4 of Set 6 | sitka
# Processing Record 5 of Set 6 | upernavik
# Processing Record 6 of Set 6 | aulum
# Processing Record 7 of Set 6 | naberera
# Processing Record 8 of Set 6 | tadine
# Processing Record 9 of Set 6 | lima
# Processing Record 10 of Set 6 | alugan
# Processing Record 11 of Set 6 | flinders
# Processing Record 12 of Set 6 | ust-koksa
# Processing Record 13 of Set 6 | uniao
# Processing Record 14 of Set 6 | richards bay
# Processing Record 15 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 6 | fortuna
# Processing Record 17 of Set 6 | sampit
# Processing Record 18 of Set 6 | kaitangata
# Processing Record 19 of Set 6 | puerto carreno
# Processing Record 20 of Set 6 | wilmington
# Processing Record 21 of Set 6 | kidal
# Processing Record 22 of Set 6 | palana
# Processing Record 23 of Set 6 | katsuura
# Processing Record 24 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 6 | vao
# Processing Record 26 of Set 6 | khatanga
# Processing Record 27 of Set 6 | quatre cocos
# Processing Record 28 of Set 6 | zapolyarnyy
# Processing Record 29 of Set 6 | faya
# Processing Record 30 of Set 6 | la ronge
# Processing Record 31 of Set 6 | bettiah
# Processing Record 32 of Set 6 | manggar
# Processing Record 33 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 6 | severo-kurilsk
# Processing Record 35 of Set 6 | ilulissat
# Processing Record 36 of Set 6 | dobryatino
# Processing Record 37 of Set 6 | kokkola
# Processing Record 38 of Set 6 | salalah
# Processing Record 39 of Set 6 | cabra
# Processing Record 40 of Set 6 | mega
# Processing Record 41 of Set 6 | sarandi
# Processing Record 42 of Set 6 | nouadhibou
# Processing Record 43 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 44 of Set 6 | seoul
# Processing Record 45 of Set 6 | santa maria
# Processing Record 46 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 6 | evanston
# Processing Record 48 of Set 6 | awjilah
# Processing Record 49 of Set 6 | swan river
# Processing Record 50 of Set 6 | kingsville
# Processing Record 1 of Set 7 | hlotse
# Processing Record 2 of Set 7 | kerzhenets
# City not found. Skipping...
# Processing Record 3 of Set 7 | ponta do sol
# Processing Record 4 of Set 7 | oktyabrskoye
# Processing Record 5 of Set 7 | nueva concepcion
# Processing Record 6 of Set 7 | liverpool
# Processing Record 7 of Set 7 | sinnai
# Processing Record 8 of Set 7 | danielskuil
# Processing Record 9 of Set 7 | berlevag
# Processing Record 10 of Set 7 | sioux falls
# Processing Record 11 of Set 7 | provideniya
# Processing Record 12 of Set 7 | razdolinsk
# Processing Record 13 of Set 7 | wadena
# Processing Record 14 of Set 7 | clyde river
# Processing Record 15 of Set 7 | waingapu
# Processing Record 16 of Set 7 | pasighat
# Processing Record 17 of Set 7 | san quintin
# Processing Record 18 of Set 7 | touros
# Processing Record 19 of Set 7 | edson
# Processing Record 20 of Set 7 | taltal
# Processing Record 21 of Set 7 | te anau
# Processing Record 22 of Set 7 | deep river
# Processing Record 23 of Set 7 | storforshei
# Processing Record 24 of Set 7 | whitianga
# Processing Record 25 of Set 7 | lunenburg
# Processing Record 26 of Set 7 | quelimane
# Processing Record 27 of Set 7 | bud
# Processing Record 28 of Set 7 | hanzhong
# Processing Record 29 of Set 7 | vikulovo
# Processing Record 30 of Set 7 | tiruvalla
# Processing Record 31 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 7 | pisco
# Processing Record 33 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 7 | acurenam
# Processing Record 35 of Set 7 | makakilo city
# Processing Record 36 of Set 7 | jardim
# Processing Record 37 of Set 7 | ilhabela
# Processing Record 38 of Set 7 | betera
# Processing Record 39 of Set 7 | naze
# Processing Record 40 of Set 7 | rawlins
# Processing Record 41 of Set 7 | maniitsoq
# Processing Record 42 of Set 7 | mehamn
# Processing Record 43 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 7 | adrar
# Processing Record 46 of Set 7 | port macquarie
# Processing Record 47 of Set 7 | ullapool
# Processing Record 48 of Set 7 | yangjiang
# Processing Record 49 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 50 of Set 7 | sabha
# Processing Record 1 of Set 8 | vila do maio
# Processing Record 2 of Set 8 | uberlandia
# Processing Record 3 of Set 8 | neepawa
# Processing Record 4 of Set 8 | la paz
# Processing Record 5 of Set 8 | tucupita
# Processing Record 6 of Set 8 | redmond
# Processing Record 7 of Set 8 | taldan
# Processing Record 8 of Set 8 | black river
# Processing Record 9 of Set 8 | puerto maldonado
# Processing Record 10 of Set 8 | groningen
# Processing Record 11 of Set 8 | husavik
# Processing Record 12 of Set 8 | ahipara
# Processing Record 13 of Set 8 | phuket
# Processing Record 14 of Set 8 | tura
# Processing Record 15 of Set 8 | djibo
# Processing Record 16 of Set 8 | hegang
# Processing Record 17 of Set 8 | paamiut
# Processing Record 18 of Set 8 | jishou
# Processing Record 19 of Set 8 | pangnirtung
# Processing Record 20 of Set 8 | nhulunbuy
# Processing Record 21 of Set 8 | mecca
# Processing Record 22 of Set 8 | marshall
# Processing Record 23 of Set 8 | namatanai
# Processing Record 24 of Set 8 | lancaster
# Processing Record 25 of Set 8 | bow island
# Processing Record 26 of Set 8 | huilong
# Processing Record 27 of Set 8 | abdanan
# Processing Record 28 of Set 8 | batsfjord
# Processing Record 29 of Set 8 | mozarlandia
# Processing Record 30 of Set 8 | klaksvik
# Processing Record 31 of Set 8 | santo angelo
# Processing Record 32 of Set 8 | kathu
# Processing Record 33 of Set 8 | saint-augustin
# Processing Record 34 of Set 8 | kirya
# Processing Record 35 of Set 8 | zhezkazgan
# Processing Record 36 of Set 8 | taitung
# Processing Record 37 of Set 8 | faanui
# Processing Record 38 of Set 8 | halifax
# Processing Record 39 of Set 8 | alexandria
# Processing Record 40 of Set 8 | byron bay
# Processing Record 41 of Set 8 | dotnuva
# Processing Record 42 of Set 8 | borogontsy
# Processing Record 43 of Set 8 | tondano
# Processing Record 44 of Set 8 | ubeda
# Processing Record 45 of Set 8 | russell
# Processing Record 46 of Set 8 | jalu
# Processing Record 47 of Set 8 | conde
# Processing Record 48 of Set 8 | hasaki
# Processing Record 49 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 8 | vadso
# Processing Record 1 of Set 9 | anadyr
# Processing Record 2 of Set 9 | arraial do cabo
# Processing Record 3 of Set 9 | hambantota
# Processing Record 4 of Set 9 | lucapa
# Processing Record 5 of Set 9 | ulaanbaatar
# Processing Record 6 of Set 9 | fort nelson
# Processing Record 7 of Set 9 | jiuquan
# Processing Record 8 of Set 9 | pringsewu
# Processing Record 9 of Set 9 | sussex
# Processing Record 10 of Set 9 | selty
# Processing Record 11 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 12 of Set 9 | leeton
# Processing Record 13 of Set 9 | margosatubig
# Processing Record 14 of Set 9 | ancud
# Processing Record 15 of Set 9 | chumikan
# Processing Record 16 of Set 9 | talnakh
# Processing Record 17 of Set 9 | iqaluit
# Processing Record 18 of Set 9 | kahului
# Processing Record 19 of Set 9 | da lat
# Processing Record 20 of Set 9 | lasa
# Processing Record 21 of Set 9 | khani
# Processing Record 22 of Set 9 | lodwar
# Processing Record 23 of Set 9 | siilinjarvi
# Processing Record 24 of Set 9 | iralaya
# Processing Record 25 of Set 9 | haldibari
# Processing Record 26 of Set 9 | zhanaozen
# Processing Record 27 of Set 9 | krasnomayskiy
# Processing Record 28 of Set 9 | vallenar
# Processing Record 29 of Set 9 | rivadavia
# Processing Record 30 of Set 9 | griffith
# Processing Record 31 of Set 9 | awbari
# Processing Record 32 of Set 9 | kjollefjord
# Processing Record 33 of Set 9 | kant
# Processing Record 34 of Set 9 | erice
# Processing Record 35 of Set 9 | praya
# Processing Record 36 of Set 9 | west wendover
# Processing Record 37 of Set 9 | ubajara
# Processing Record 38 of Set 9 | khandyga
# Processing Record 39 of Set 9 | neiafu
# Processing Record 40 of Set 9 | marienburg
# Processing Record 41 of Set 9 | dianopolis
# City not found. Skipping...
# Processing Record 42 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 9 | ferme-neuve
# Processing Record 44 of Set 9 | kutum
# Processing Record 45 of Set 9 | san vicente
# Processing Record 46 of Set 9 | beloha
# Processing Record 47 of Set 9 | arys
# Processing Record 48 of Set 9 | arona
# Processing Record 49 of Set 9 | caravelas
# Processing Record 50 of Set 9 | tahta
# Processing Record 1 of Set 10 | mola di bari
# Processing Record 2 of Set 10 | dzhebariki-khaya
# Processing Record 3 of Set 10 | las vegas
# Processing Record 4 of Set 10 | gushikawa
# Processing Record 5 of Set 10 | erzincan
# Processing Record 6 of Set 10 | hede
# Processing Record 7 of Set 10 | kesan
# Processing Record 8 of Set 10 | vila velha
# Processing Record 9 of Set 10 | constitucion
# Processing Record 10 of Set 10 | northam
# Processing Record 11 of Set 10 | harper
# Processing Record 12 of Set 10 | chalus
# Processing Record 13 of Set 10 | namibe
# Processing Record 14 of Set 10 | belaya gora
# Processing Record 15 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 10 | la baule-escoublac
# Processing Record 17 of Set 10 | magole
# Processing Record 18 of Set 10 | eureka
# Processing Record 19 of Set 10 | vardo
# Processing Record 20 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 21 of Set 10 | claudio
# Processing Record 22 of Set 10 | yumen
# Processing Record 23 of Set 10 | qaqortoq
# Processing Record 24 of Set 10 | mantua
# Processing Record 25 of Set 10 | isla mujeres
# Processing Record 26 of Set 10 | sergeyevka
# Processing Record 27 of Set 10 | indramayu
# Processing Record 28 of Set 10 | roncesvalles
# Processing Record 29 of Set 10 | araouane
# Processing Record 30 of Set 10 | banda aceh
# Processing Record 31 of Set 10 | tessalit
# Processing Record 32 of Set 10 | zilair
# Processing Record 33 of Set 10 | gigmoto
# Processing Record 34 of Set 10 | bairiki
# Processing Record 35 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 36 of Set 10 | rio de janeiro
# Processing Record 37 of Set 10 | sosva
# Processing Record 38 of Set 10 | haapu
# City not found. Skipping...
# Processing Record 39 of Set 10 | arrecife
# Processing Record 40 of Set 10 | vasterhaninge
# Processing Record 41 of Set 10 | morong
# Processing Record 42 of Set 10 | morehead
# Processing Record 43 of Set 10 | batagay
# Processing Record 44 of Set 10 | svetlyy
# Processing Record 45 of Set 10 | taoudenni
# Processing Record 46 of Set 10 | tilichiki
# Processing Record 47 of Set 10 | okhotsk
# Processing Record 48 of Set 10 | barcelos
# Processing Record 49 of Set 10 | maketu
# Processing Record 50 of Set 10 | siparia
# Processing Record 1 of Set 11 | hailey
# Processing Record 2 of Set 11 | maple heights
# Processing Record 3 of Set 11 | roma
# Processing Record 4 of Set 11 | asilah
# Processing Record 5 of Set 11 | sao miguel do araguaia
# Processing Record 6 of Set 11 | kieta
# Processing Record 7 of Set 11 | quesnel
# Processing Record 8 of Set 11 | adeje
# Processing Record 9 of Set 11 | rawson
# Processing Record 10 of Set 11 | chatra
# Processing Record 11 of Set 11 | bereznik
# Processing Record 12 of Set 11 | zhangye
# Processing Record 13 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 11 | gorontalo
# Processing Record 15 of Set 11 | male
# Processing Record 16 of Set 11 | shenzhen
# Processing Record 17 of Set 11 | arklow
# Processing Record 18 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 11 | thinadhoo
# Processing Record 20 of Set 11 | mitzic
# Processing Record 21 of Set 11 | tornio
# Processing Record 22 of Set 11 | owensboro
# Processing Record 23 of Set 11 | ust-omchug
# Processing Record 24 of Set 11 | kirksville
# Processing Record 25 of Set 11 | collie
# Processing Record 26 of Set 11 | odweyne
# Processing Record 27 of Set 11 | skibbereen
# Processing Record 28 of Set 11 | vila franca do campo
# Processing Record 29 of Set 11 | yar-sale
# Processing Record 30 of Set 11 | yarmouth
# Processing Record 31 of Set 11 | nanortalik
# Processing Record 32 of Set 11 | svetlogorsk
# Processing Record 33 of Set 11 | dingli
# Processing Record 34 of Set 11 | kletnya
# Processing Record 35 of Set 11 | general cepeda
# Processing Record 36 of Set 11 | ornskoldsvik
# Processing Record 37 of Set 11 | ferrol
# Processing Record 38 of Set 11 | atar
# Processing Record 39 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 40 of Set 11 | abu samrah
# Processing Record 41 of Set 11 | borba
# Processing Record 42 of Set 11 | covington
# Processing Record 43 of Set 11 | tottori
# Processing Record 44 of Set 11 | jijiga
# Processing Record 45 of Set 11 | lagoa
# Processing Record 46 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 11 | floro
# Processing Record 48 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 49 of Set 11 | fairbanks
# Processing Record 50 of Set 11 | izumo
# Processing Record 1 of Set 12 | paita
# Processing Record 2 of Set 12 | bonavista
# Processing Record 3 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 4 of Set 12 | narsaq
# Processing Record 5 of Set 12 | beaverlodge
# Processing Record 6 of Set 12 | grindavik
# Processing Record 7 of Set 12 | adrian
# Processing Record 8 of Set 12 | sept-iles
# Processing Record 9 of Set 12 | manokwari
# Processing Record 10 of Set 12 | cartagena
# Processing Record 11 of Set 12 | gondanglegi
# Processing Record 12 of Set 12 | salinopolis
# Processing Record 13 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 12 | gat
# Processing Record 15 of Set 12 | progreso
# Processing Record 16 of Set 12 | antsohihy
# Processing Record 17 of Set 12 | kavant
# City not found. Skipping...
# Processing Record 18 of Set 12 | tessaoua
# Processing Record 19 of Set 12 | tarakan
# Processing Record 20 of Set 12 | talipan
# Processing Record 21 of Set 12 | gubbi
# Processing Record 22 of Set 12 | mumford
# Processing Record 23 of Set 12 | kindu
# Processing Record 24 of Set 12 | krasnoznamensk
# Processing Record 25 of Set 12 | kaniama
# Processing Record 26 of Set 12 | itanhem
# Processing Record 27 of Set 12 | north bend
# Processing Record 28 of Set 12 | dromolaxia
# Processing Record 29 of Set 12 | basco
# Processing Record 30 of Set 12 | camacha
# Processing Record 31 of Set 12 | rathdrum
# Processing Record 32 of Set 12 | bolobo
# Processing Record 33 of Set 12 | kapit
# Processing Record 34 of Set 12 | yaan
# Processing Record 35 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 36 of Set 12 | longyearbyen
# Processing Record 37 of Set 12 | novyy urengoy
# Processing Record 38 of Set 12 | tocantins
# Processing Record 39 of Set 12 | eydhafushi
# Processing Record 40 of Set 12 | meghri
# Processing Record 41 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 12 | pumiao
# Processing Record 43 of Set 12 | ingham
# Processing Record 44 of Set 12 | carman
# Processing Record 45 of Set 12 | lethbridge
# Processing Record 46 of Set 12 | lompoc
# Processing Record 47 of Set 12 | zolotinka
# City not found. Skipping...
# Processing Record 48 of Set 12 | borgarnes
# Processing Record 49 of Set 12 | boda
# Processing Record 50 of Set 12 | kununurra
# Processing Record 1 of Set 13 | arman
# Processing Record 2 of Set 13 | pascagoula
# Processing Record 3 of Set 13 | kayerkan
# Processing Record 4 of Set 13 | smithers
# Processing Record 5 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 6 of Set 13 | fort saint james
# Processing Record 7 of Set 13 | kushmurun
# Processing Record 8 of Set 13 | majene
# Processing Record 9 of Set 13 | tsimlyansk
# Processing Record 10 of Set 13 | dakoro
# Processing Record 11 of Set 13 | bahia blanca
# Processing Record 12 of Set 13 | wilson
# Processing Record 13 of Set 13 | ksenyevka
# City not found. Skipping...
# Processing Record 14 of Set 13 | itaberai
# Processing Record 15 of Set 13 | san carlos
# Processing Record 16 of Set 13 | kulhudhuffushi
# Processing Record 17 of Set 13 | bodden town
# Processing Record 18 of Set 13 | bela
# Processing Record 19 of Set 13 | celestun
# Processing Record 20 of Set 13 | usak
# Processing Record 21 of Set 13 | dahuk
# Processing Record 22 of Set 13 | calvinia
# Processing Record 23 of Set 13 | celendin
# Processing Record 24 of Set 13 | honiara
# Processing Record 25 of Set 13 | vuktyl
# Processing Record 26 of Set 13 | tezu
# Processing Record 27 of Set 13 | kamenka
# Processing Record 28 of Set 13 | lavrentiya
# Processing Record 29 of Set 13 | takestan
# Processing Record 30 of Set 13 | xichang
# Processing Record 31 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 13 | lemoore
# Processing Record 33 of Set 13 | porto novo
# Processing Record 34 of Set 13 | ust-uda
# Processing Record 35 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 36 of Set 13 | aksu
# Processing Record 37 of Set 13 | bure
# Processing Record 38 of Set 13 | kalmunai
# Processing Record 39 of Set 13 | tselinnoye
# Processing Record 40 of Set 13 | ivanteyevka
# Processing Record 41 of Set 13 | kodino
# Processing Record 42 of Set 13 | itarema
# Processing Record 43 of Set 13 | abha
# Processing Record 44 of Set 13 | kiunga
# Processing Record 45 of Set 13 | joue-les-tours
# Processing Record 46 of Set 13 | salekhard
# Processing Record 47 of Set 13 | rio cuarto
# Processing Record 48 of Set 13 | zaysan
# Processing Record 49 of Set 13 | kaspiyskiy
# Processing Record 50 of Set 13 | prince rupert
# Processing Record 1 of Set 14 | opuwo
# Processing Record 2 of Set 14 | huancabamba
# Processing Record 3 of Set 14 | utrecht
# Processing Record 4 of Set 14 | deniliquin
# Processing Record 5 of Set 14 | urumqi
# Processing Record 6 of Set 14 | were ilu
# Processing Record 7 of Set 14 | losevo
# Processing Record 8 of Set 14 | biak
# Processing Record 9 of Set 14 | sangar
# Processing Record 10 of Set 14 | waddan
# Processing Record 11 of Set 14 | zeya
# Processing Record 12 of Set 14 | kailua
# Processing Record 13 of Set 14 | komsomolskiy
# Processing Record 14 of Set 14 | khrustalnyy
# City not found. Skipping...
# Processing Record 15 of Set 14 | belle fourche
# Processing Record 16 of Set 14 | chulman
# Processing Record 17 of Set 14 | tiznit
# Processing Record 18 of Set 14 | bajo baudo
# City not found. Skipping...
# Processing Record 19 of Set 14 | broken hill
# Processing Record 20 of Set 14 | sehwan
# Processing Record 21 of Set 14 | hokitika
# Processing Record 22 of Set 14 | taketa
# Processing Record 23 of Set 14 | tawang
# Processing Record 24 of Set 14 | raton
# Processing Record 25 of Set 14 | marsassoum
# Processing Record 26 of Set 14 | chernenko
# Processing Record 27 of Set 14 | nipawin
# Processing Record 28 of Set 14 | ranong
# Processing Record 29 of Set 14 | huarmey
# Processing Record 30 of Set 14 | enumclaw
# Processing Record 31 of Set 14 | hvittingfoss
# Processing Record 32 of Set 14 | rio grande
# Processing Record 33 of Set 14 | balkanabat
# Processing Record 34 of Set 14 | astara
# Processing Record 35 of Set 14 | cabildo
# Processing Record 36 of Set 14 | saldanha
# Processing Record 37 of Set 14 | tabou
# Processing Record 38 of Set 14 | gobabis
# Processing Record 39 of Set 14 | acapulco
# Processing Record 40 of Set 14 | tommot
# Processing Record 41 of Set 14 | bakchar
# Processing Record 42 of Set 14 | ongandjera
# Processing Record 43 of Set 14 | egvekinot
# Processing Record 44 of Set 14 | motygino
# Processing Record 45 of Set 14 | pangody
# Processing Record 46 of Set 14 | vitim
# Processing Record 47 of Set 14 | lysva
# Processing Record 48 of Set 14 | ruteng
# Processing Record 49 of Set 14 | henties bay
# Processing Record 50 of Set 14 | asosa
# Processing Record 1 of Set 15 | ambilobe
# Processing Record 2 of Set 15 | tlaltenango
# Processing Record 3 of Set 15 | lata
# Processing Record 4 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 15 | odienne
# Processing Record 6 of Set 15 | chapais
# Processing Record 7 of Set 15 | puerto baquerizo moreno
# Processing Record 8 of Set 15 | sao gabriel da cachoeira
# Processing Record 9 of Set 15 | ossora
# Processing Record 10 of Set 15 | hachinohe
# Processing Record 11 of Set 15 | portland
# Processing Record 12 of Set 15 | khash
# Processing Record 13 of Set 15 | aquiraz
# Processing Record 14 of Set 15 | darhan
# Processing Record 15 of Set 15 | grand gaube
# Processing Record 16 of Set 15 | oparino
# Processing Record 17 of Set 15 | balabac
# Processing Record 18 of Set 15 | missoula
# Processing Record 19 of Set 15 | mahon
# Processing Record 20 of Set 15 | aripuana
# Processing Record 21 of Set 15 | sur
# Processing Record 22 of Set 15 | neyshabur
# Processing Record 23 of Set 15 | podgornaya
# Processing Record 24 of Set 15 | khatra
# Processing Record 25 of Set 15 | simbahan
# Processing Record 26 of Set 15 | mae sai
# Processing Record 27 of Set 15 | sorland
# Processing Record 28 of Set 15 | hervey bay
# Processing Record 29 of Set 15 | ushtobe
# Processing Record 30 of Set 15 | sabang
# Processing Record 31 of Set 15 | shingu
# Processing Record 32 of Set 15 | camocim
# Processing Record 33 of Set 15 | gogrial
# Processing Record 34 of Set 15 | kabanjahe
# Processing Record 35 of Set 15 | tikhvin
# Processing Record 36 of Set 15 | galveston
# Processing Record 37 of Set 15 | acajutla
# Processing Record 38 of Set 15 | gelemso
# Processing Record 39 of Set 15 | bukachacha
# Processing Record 40 of Set 15 | college
# Processing Record 41 of Set 15 | sistranda
# Processing Record 42 of Set 15 | kracheh
# City not found. Skipping...
# Processing Record 43 of Set 15 | sokoni
# Processing Record 44 of Set 15 | labuhan
# Processing Record 45 of Set 15 | puerto del rosario
# Processing Record 46 of Set 15 | krasnoborsk
# Processing Record 47 of Set 15 | ramhormoz
# Processing Record 48 of Set 15 | muisne
# Processing Record 49 of Set 15 | devils lake
# Processing Record 50 of Set 15 | hvolsvollur
# Processing Record 1 of Set 16 | kuching
# Processing Record 2 of Set 16 | achisay
# City not found. Skipping...
# Processing Record 3 of Set 16 | stornoway
# Processing Record 4 of Set 16 | kristianstad
# Processing Record 5 of Set 16 | yerbogachen
# Processing Record 6 of Set 16 | bilibino
# Processing Record 7 of Set 16 | fevralsk
# City not found. Skipping...
# Processing Record 8 of Set 16 | mopti
# Processing Record 9 of Set 16 | chany
# Processing Record 10 of Set 16 | formosa
# Processing Record 11 of Set 16 | nortelandia
# Processing Record 12 of Set 16 | cangucu
# Processing Record 13 of Set 16 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 16 | port keats
# Processing Record 15 of Set 16 | maple creek
# Processing Record 16 of Set 16 | suoyarvi
# Processing Record 17 of Set 16 | balgazyn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Ushuaia      AR -54.8000  -68.3000     53.26        47          20
# 1       Airai      TL  -8.9266  125.4092     60.69        96          58
# 2      Barrow      US  71.2906 -156.7887     21.22        93         100
# 3      Albany      US  42.6001  -73.9662     60.46        34         100
# 4     Aklavik      CA  68.2191 -135.0107     39.20        56          20
# 5      Davila      PH  18.4726  120.5763     82.08        77          99
# 6     Yueyang      CN  29.3333  113.0919     70.11        83          88
# 7      Bethel      US  41.3712  -73.4140     54.36        57          75
# 8  Nikolskoye      RU  59.7035   30.7861     52.72        86          99
# 9     Lakselv      NO  70.0513   24.9718     37.22        65          40
#
#    Wind Speed Current Description
# 0       17.27          few clouds
# 1        4.50       broken clouds
# 2       10.36     overcast clouds
# 3        3.00     overcast clouds
# 4        9.22          few clouds
# 5        5.75     overcast clouds
# 6        1.23     overcast clouds
# 7       14.97       broken clouds
# 8        3.13     overcast clouds
# 9       10.36    scattered clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
